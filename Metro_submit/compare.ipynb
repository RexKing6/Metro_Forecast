# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = (300,5)
plt.rcParams['font.sans-serif'] = ['SimHei']    # 定义使其正常显示中文字体黑体
plt.rcParams['axes.unicode_minus'] = False      # 用来正常显示表示负号

# %%
dfs = {}
dfs['28'] = pd.read_csv('testA_submit_2019-01-29_直接28.csv')
dfs['aver'] = pd.read_csv('testA_submit_2019-01-29_平均.csv')
dfs['lr'] = pd.read_csv('testA_submit_2019-01-29_线性回归+四舍五入.csv')
dfs['lstm_weekday&end'] = pd.read_csv('testA_submit_2019-01-29_LSTM_weekday&end.csv')
dfs['lstm_weekday'] = pd.read_csv('testA_submit_2019-01-29_LSTM_only weekday.csv')

# %%
for i in dfs.keys():
    plt.plot(dfs[i]['inNums'],label=i)
plt.xlim(-10, 11650)
plt.legend()
plt.show()

# %% [markdown]
# LSTM在每一站的第一个高峰效果还不错，在第二个高峰直接平缓，初步估计是非工作日的影响，加入的工作日特征没有发挥作用。试试训练时不加入非工作日样本。

# %% [markdown]
# 上面说的没用。0.0
